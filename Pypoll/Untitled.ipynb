# %%
import pandas as pd
import numpy as np
import sys

# %%
# Create reference to CSV file
csv_path1 = "raw_data/election_data_1.csv"
csv_path2 = "raw_data/election_data_2.csv"

# %%
elecD1 = pd.read_csv(csv_path1)
elecD2 = pd.read_csv(csv_path2)
elecD1.head()
# Out:
#    Voter ID      County Candidate
# 0   1405627      Harsaw    Vestal
# 1   1711723  Mershville    Vestal
# 2   1550639  Matterdawn    Vestal
# 3   1042621      Harsaw    Vestal
# 4   1583965  Matterdawn    Vestal

# %%
#Total Number of Votes
Votes1 = len(elecD1.index)
Votes2 = len(elecD2.index)
TotVotes = Votes1 + Votes2

# %%
#Get Unique Candidates
Candidates1 = elecD1.Candidate.unique()
Candidates2 = elecD2.Candidate.unique()

# %%
#Print list of Candidates
#print("List of Candidates that recieved votes:")
#print(*Candidates1, sep = "\n")
#print(*Candidates2, sep = "\n")

# %%
# Candidates1 = elecD1['Candidate'].value_counts().index.tolist
# Votes1 = elecD1['Candidate'].value_counts().tolist
# Candidates2 = elecD2['Candidate'].value_counts().keys().tolist
# Votes2 = elecD2['Candidate'].value_counts().tolist

# %%
for column in elecD1:
    if elecD1["Candidates"]==
    print(elecD1[column])
# Out:
# 0         1405627
# 1         1711723
# 2         1550639
# 3         1042621
# 4         1583965
# 5         1943299
# 6         1880982
# 7         1305689
# 8         1759114
# 9         1745020
# 10        1562401
# 11        1467337
# 12        1091170
# 13        1947604
# 14        1400758
# 15        1009045
# 16        1246891
# 17        1744120
# 18        1571939
# 19        1936895
# 20        1122582
# 21        1307503
# 22        1594030
# 23        1072081
# 24        1368919
# 25        1954121
# 26        1427438
# 27        1049416
# 28        1619112
# 29        1725473
#            ...
# 802970    1243711
# 802971    1165617
# 802972    1536635
# 802973    1952569
# 802974    1900901
# 802975    1623227
# 802976    1164899
# 802977    1430310
# 802978    1421648
# 802979    1966539
# 802980    1048447
# 802981    1220171
# 802982    1546597
# 802983    1454316
# 802984    1273447
# 802985    1642944
# 802986    1009803
# 802987    1348943
# 802988    1984510
# ...
